# %%
import pandas as pd
from src.load import load_data, merge_dataframes

file_paths = [
    "../data/Monthly_Summary_Solar.csv",
    "../data/Solar_Energy_Generation.csv",
    "../data/Solar_Site_Details.csv",
    "../data/Weather_Data_reordered_all.csv"
]
